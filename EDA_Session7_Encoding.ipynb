# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv("Visadataset.csv")
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
types=visa_df.dtypes
cat_columns=[key for key,value in types.items() if value=='object']
num_columns=[key for key,value in types.items() if value!='object']

# %% [markdown]
# **Encoding**
#
# - Encoding means convert categorical columns data to Numerical data
# - Because ML models Except the data should be in Numerical format
# - ML model developed by Math algorithms
# - It is very very important to apply encoding
# - The following methods are
#    - map
#    - np.where
#    - one hot encoding
#    - Label Encoder

# %% [markdown]
# **Map**
#
# - Mapping is one method to convert categorical values to numerical
# - Take one categorical column
# - Get the unique labels first
# - make a dictionary with assign a number to each label
# - for example case_status has two labels
#      - Certified
#      - Denied
# - Assign 0 to Certified, 1 to Denied
# - Create a dictionary labels as keys,number as values only
# - {'Certified':0,'Denied':1}

# %%
# step-1:read the column
# step-2:get the unique labels
# step-3: make a dictionary
# step-4: apply the map

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_staus_new']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new
# 0          Denied               1
# 1       Certified               0
# 2          Denied               1
# 3          Denied               1
# 4       Certified               0
# ...           ...             ...
# 25475   Certified               0
# 25476   Certified               0
# 25477   Certified               0
# 25478   Certified               0
# 25479   Certified               0
#
# [25480 rows x 13 columns]

# %%
num_columns
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d={'Asia':0, 'Africa':1, 'North America':2, 'Europe':3, 'South America':4,
       'Oceania':5}
visa_df['continent_new']=visa_df['continent'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new
# 0          Denied               1              0
# 1       Certified               0              0
# 2          Denied               1              0
# 3          Denied               1              0
# 4       Certified               0              1
# ...           ...             ...            ...
# 25475   Certified               0              0
# 25476   Certified               0              0
# 25477   Certified               0              0
# 25478   Certified               0              0
# 25479   Certified               0              0
#
# [25480 rows x 14 columns]

# %%
cat_columns
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
# Perform the Map method for all categorical columns

# 1. Automatically get the labels
# 2. Create a dictionary to map the numbers with labels
# 3. apply into cat column using map

# create a function to do above there and pass the cat columns list and convert it

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
d={'High School':0, "Master's":1, "Bachelor's":2, 'Doctorate':3}
visa_df['education_of_employee_new']=visa_df['education_of_employee'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new  education_of_employee_new
# 0          Denied               1              0                          0
# 1       Certified               0              0                          1
# 2          Denied               1              0                          2
# 3          Denied               1              0                          2
# 4       Certified               0              1                          1
# ...           ...             ...            ...                        ...
# 25475   Certified               0              0                          2
# 25476   Certified               0              0                          0
# 25477   Certified               0              0                          1
# 25478   Certified               0              0                          1
# 25479   Certified               0              0                          2
#
# [25480 rows x 15 columns]

# %%
visa_df['has_job_experience'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
d={'N':0, 'Y':1}
visa_df['has_job_experience_new']=visa_df['has_job_experience'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new  education_of_employee_new  \
# 0          Denied               1              0                          0
# 1       Certified               0              0                          1
# 2          Denied               1              0                          2
# 3          Denied               1              0                          2
# 4       Certified               0              1                          1
# ...           ...             ...            ...                        ...
# 25475   Certified               0              0                          2
# 25476   Certified               0              0                          0
# 25477   Certified               0              0                          1
# 25478   Certified               0              0                          1
# 25479   Certified               0              0                          2
#
#        has_job_experience_new
# 0                           0
# 1                           1
# 2                           0
# 3                           0
# 4                           1
# ...                       ...
# 25475                       1
# 25476                       1
# 25477                       1
# 25478                       1
# 25479                       1
#
# [25480 rows x 16 columns]

# %%
visa_df['requires_job_training'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
d={'N':0, 'Y':1}
visa_df['requires_job_training_new']=visa_df['requires_job_training'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new  education_of_employee_new  \
# 0          Denied               1              0                          0
# 1       Certified               0              0                          1
# 2          Denied               1              0                          2
# 3          Denied               1              0                          2
# 4       Certified               0              1                          1
# ...           ...             ...            ...                        ...
# 25475   Certified               0              0                          2
# 25476   Certified               0              0                          0
# 25477   Certified               0              0                          1
# 25478   Certified               0              0                          1
# 25479   Certified               0              0                          2
#
#        has_job_experience_new  requires_job_training_new
# 0                           0                          0
# 1                           1                          0
# 2                           0                          1
# 3                           0                          0
# 4                           1                          0
# ...                       ...                        ...
# 25475                       1                          1
# 25476                       1                          0
# 25477                       1                          0
# 25478                       1                          1
# 25479                       1                          0
#
# [25480 rows x 17 columns]

# %%
visa_df['region_of_employment'].unique()
# Out:
# array(['West', 'Northeast', 'South', 'Midwest', 'Island'], dtype=object)

# %%
d={'West':0, 'Northeast':1, 'South':2, 'Midwest':3, 'Island':4}
visa_df['region_of_employment_new']=visa_df['region_of_employment'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new  education_of_employee_new  \
# 0          Denied               1              0                          0
# 1       Certified               0              0                          1
# 2          Denied               1              0                          2
# 3          Denied               1              0                          2
# 4       Certified               0              1                          1
# ...           ...             ...            ...                        ...
# 25475   Certified               0              0                          2
# 25476   Certified               0              0                          0
# 25477   Certified               0              0                          1
# 25478   Certified               0              0                          1
# 25479   Certified               0              0                          2
#
#        has_job_experience_new  requires_job_training_new  \
# 0                           0                          0
# 1                           1                          0
# 2                           0                          1
# 3                           0                          0
# 4                           1                          0
# ...                       ...                        ...
# 25475                       1                          1
# 25476                       1                          0
# 25477                       1                          0
# 25478                       1                          1
# 25479                       1                          0
#
#        region_of_employment_new
# 0                             0
# 1                             1
# 2                             0
# 3                             0
# 4                             2
# ...                         ...
# 25475                         2
# 25476                         1
# 25477                         2
# 25478                         0
# 25479                         3
#
# [25480 rows x 18 columns]

# %%
visa_df['unit_of_wage'].unique()
# Out:
# array(['Hour', 'Year', 'Week', 'Month'], dtype=object)

# %%
d={'Hour':0, 'Year':1, 'Week':2, 'Month':3}
visa_df['unit_of_wage_new']=visa_df['unit_of_wage'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new  education_of_employee_new  \
# 0          Denied               1              0                          0
# 1       Certified               0              0                          1
# 2          Denied               1              0                          2
# 3          Denied               1              0                          2
# 4       Certified               0              1                          1
# ...           ...             ...            ...                        ...
# 25475   Certified               0              0                          2
# 25476   Certified               0              0                          0
# 25477   Certified               0              0                          1
# 25478   Certified               0              0                          1
# 25479   Certified               0              0                          2
#
#        has_job_experience_new  requires_job_training_new  \
# 0                           0                          0
# 1                           1                          0
# 2                           0                          1
# 3                           0                          0
# 4                           1                          0
# ...                       ...                        ...
# 25475                       1                          1
# 25476                       1                          0
# 25477                       1                          0
# 25478                       1                          1
# 25479                       1                          0
#
#        region_of_employment_new  unit_of_wage_new
# 0                             0                 0
# 1                             1                 1
# 2                             0                 1
# 3                             0                 1
# 4                             2                 1
# ...                         ...               ...
# 25475                         2                 1
# 25476                         1                 1
# 25477                         2                 1
# 25478                         0                 1
# 25479                         3                 1
#
# [25480 rows x 19 columns]

# %%
visa_df['full_time_position'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
d={'Y':0, 'N':1}
visa_df['full_time_position_new']=visa_df['full_time_position'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_staus_new  continent_new  education_of_employee_new  \
# 0          Denied               1              0                          0
# 1       Certified               0              0                          1
# 2          Denied               1              0                          2
# 3          Denied               1              0                          2
# 4       Certified               0              1                          1
# ...           ...             ...            ...                        ...
# 25475   Certified               0              0                          2
# 25476   Certified               0              0                          0
# 25477   Certified               0              0                          1
# 25478   Certified               0              0                          1
# 25479   Certified               0              0                          2
#
#        has_job_experience_new  requires_job_training_new  \
# 0                           0                          1
# 1                           1                          1
# 2                           0                          0
# 3                           0                          1
# 4                           1                          1
# ...                       ...                        ...
# 25475                       1                          0
# 25476                       1                          1
# 25477                       1                          1
# 25478                       1                          0
# 25479                       1                          1
#
#        region_of_employment_new  unit_of_wage_new  full_time_position_new
# 0                             0                 0                       0
# 1                             1                 1                       0
# 2                             0                 1                       0
# 3                             0                 1                       0
# 4                             2                 1                       0
# ...                         ...               ...                     ...
# 25475                         2                 1                       0
# 25476                         1                 1                       0
# 25477                         2                 1                       1
# 25478                         0                 1                       0
# 25479                         3                 1                       0
#
# [25480 rows x 20 columns]

# %%
#create a function to do above there and pass the cat columns list and convert it
l=[]
d={}
for i in cat_columns[1:]:
    col=visa_df[i].unique()
    for j in range(len(col)):
        d[col[j]]=j
    visa_df_new=visa_df[i].map(d)
    l.append(visa_df_new)
l
# Out:
# [0        0
#  1        0
#  2        0
#  3        0
#  4        1
#          ..
#  25475    0
#  25476    0
#  25477    0
#  25478    0
#  25479    0
#  Name: continent, Length: 25480, dtype: int64,
#  0        0
#  1        1
#  2        2
#  3        2
#  4        1
#          ..
#  25475    2
#  25476    0
#  25477    1
#  25478    1
#  25479    2
#  Name: education_of_employee, Length: 25480, dtype: int64,
#  0        0
#  1        1
#  2        0
#  3        0
#  4        1
#          ..
#  25475    1
#  25476    1
#  25477    1
#  25478    1
#  25479    1
#  Name: has_job_experience, Length: 25480, dtype: int64,
#  0        0
#  1        0
#  2        1
#  3        0
#  4        0
#          ..
#  25475    1
#  25476    0
#  25477    0
#  25478    1
#  25479    0
#  Name: requires_job_training, Length: 25480, dtype: int64,
#  0        0
#  1        1
#  2        0
#  3        0
#  4        2
#          ..
#  25475    2
#  25476    1
#  25477    2
#  25478    0
#  25479    3
#  Name: region_of_employment, Length: 25480, dtype: int64,
#  0        0
#  1        1
#  2        1
#  3        1
#  4        1
#          ..
#  25475    1
#  25476    1
#  25477    1
#  25478    1
#  25479    1
#  Name: unit_of_wage, Length: 25480, dtype: int64,
#  0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  25475    0
#  25476    0
#  25477    1
#  25478    0
#  25479    0
#  Name: full_time_position, Length: 25480, dtype: int64,
#  0        0
#  1        1
#  2        0
#  3        0
#  4        1
#          ..
#  25475    1
#  25476    1
#  25477    1
#  25478    1
#  25479    1
#  Name: case_status, Length: 25480, dtype: int64]

# %%
# i want to apply the map method for all categorical columns
# step-1:we need to get unique labels
# step-2: we need to get a numbers=Len unique labels
# step-3:we need to create a dictionary

# %%
unique_labels=sorted(visa_df['case_status'].unique())
list1=[i for i in range(len(unique_labels))]
dict1=dict(zip(unique_labels,list1))
dict1
visa_df['case_status']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#        case_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 25475            0
# 25476            0
# 25477            0
# 25478            0
# 25479            0
#
# [25480 rows x 12 columns]

# %%
for i in cat_columns[1:]:
    unique_labels=sorted(visa_df[i].unique())
    list1=[i for i in range(len(unique_labels))]
    dict1=dict(zip(unique_labels,list1))
    dict1
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# 1                          0             2412         2002
# 2                          1            44444         2008
# 3                          0               98         1897
# 4                          0             1082         2005
# ...                      ...              ...          ...
# 25475                      1             2601         2008
# 25476                      0             3274         2006
# 25477                      0             1121         1910
# 25478                      1             1918         1887
# 25479                      0             3195         1960
#
#        region_of_employment  prevailing_wage  unit_of_wage  \
# 0                         4         592.2029             0
# 1                         2       83425.6500             3
# 2                         4      122996.8600             3
# 3                         4       83434.0300             3
# 4                         3      149907.3900             3
# ...                     ...              ...           ...
# 25475                     3       77092.5700             3
# 25476                     2      279174.7900             3
# 25477                     3      146298.8500             3
# 25478                     4       86154.7700             3
# 25479                     1       70876.9100             3
#
#        full_time_position  case_status
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            1
# 4                       1            0
# ...                   ...          ...
# 25475                   1            0
# 25476                   1            0
# 25477                   0            0
# 25478                   1            0
# 25479                   1            0
#
# [25480 rows x 12 columns]

# %%
{key:value for key,value in zip(unique_labels,list1)}
# Out:
# {'Certified': 0, 'Denied': 1}

# %% [markdown]
# **LabelEncoder**
#
# - LabelEncoder is a method to convert categorical data to Numerical data
# - LabelEncoder is a same way,how we did in the above
# - The for loop map method we explored
# - But the LabelEncoder also do the same
# - It is under **sickit-learn** we usually called as **sklearn**
# - Under sklearn we have class called as preprocessing
# - Because currently we are doing data preprocessing only
# - under preprocessing class we have a method called as **LableEncoder**
# - sklearn
#     - preprocessing
#       - LabelEncoder
# - Any sklearn package has 3 steps
#     - Step-1:Read the package
#     - Step-2:Save the package
#     - Step-3:Apply fit transform on data

# %%
# Read the data
visa_df=pd.read_csv("Visadataset.csv")

# %%
# step-1:Read the package
from sklearn.preprocessing import LabelEncoder
# step-2:save the package
le=LabelEncoder()
# step-3:Apply fit transform on data
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#        case_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 25475            0
# 25476            0
# 25477            0
# 25478            0
# 25479            0
#
# [25480 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
visa_df=pd.read_csv("Visadataset.csv")
cat_columns=visa_df.select_dtypes(include='object').columns
# step-2:save the package
le=LabelEncoder()
for i in cat_columns:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# 1                          0             2412         2002
# 2                          1            44444         2008
# 3                          0               98         1897
# 4                          0             1082         2005
# ...                      ...              ...          ...
# 25475                      1             2601         2008
# 25476                      0             3274         2006
# 25477                      0             1121         1910
# 25478                      1             1918         1887
# 25479                      0             3195         1960
#
#        region_of_employment  prevailing_wage  unit_of_wage  \
# 0                         4         592.2029             0
# 1                         2       83425.6500             3
# 2                         4      122996.8600             3
# 3                         4       83434.0300             3
# 4                         3      149907.3900             3
# ...                     ...              ...           ...
# 25475                     3       77092.5700             3
# 25476                     2      279174.7900             3
# 25477                     3      146298.8500             3
# 25478                     4       86154.7700             3
# 25479                     1       70876.9100             3
#
#        full_time_position  case_status
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            1
# 4                       1            0
# ...                   ...          ...
# 25475                   1            0
# 25476                   1            0
# 25477                   0            0
# 25478                   1            0
# 25479                   1            0
#
# [25480 rows x 12 columns]

# %% [markdown]
# **fit and transform**
#
# - fit means develop the logic
# - transform means process the logic
# - if we observe in map method first we developed dictionary logic
# - the we apply that dictionary to column
# - Developing the dictionary is kind of fit
# - apply the dictionary to column means we are transforming the data cat to num
# - whenever we are transforming or changing the data then use **fit transform**
# - if we are not changing the data then only **fit**

# %% [markdown]
# **np.where**

# %% [markdown]
# - using np.where also we can change the Categorical data to Numerical
# - But np.where is only for binary condition
# - np.where is same as if-else
# - if condition is True:will apply True value
# - if condition is False:will apply the False value
# - so np.where use for only binary labels
# - A column should have only two unique labels

# %%
# value=='certified' replace with 0
# otherwise 1
visa_df=pd.read_csv("Visadataset.csv")
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#        case_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 25475            0
# 25476            0
# 25477            0
# 25478            0
# 25479            0
#
# [25480 rows x 12 columns]

# %% [markdown]
# **One hot encoder**
#
# - One hot means if one will be ON,another will be OFF
# - ON represents with 1
# - Off represents with 0
# - For example case status has two unique lables
#   - Certified
#   - Denied
# - One hot encoder creates new columns which is equal to number of unique labels
# - For example case status will create two new extra columns
#   - case_status_Certified
#   - case_status_Denied
# |case_status|case_status_certfied|case_status_denied
# |-|-|-|
# Denied|0|1
# Certified|1|0
# Denied|0|1
